# %%
import pandas as pd

# %%
df = pd.read_csv(
    "pos-datascience-analise-e-exploracao-de-dados-Dados\A150850189_28_143_208 (1).csv", 
    encoding='latin',
      sep=';', 
      skiprows=3, 
      skipfooter=12,
      decimal=',',
      thousands='.',
      na_values=['-']
)
# Out:
# C:\Users\corpc34475\AppData\Local\Temp\ipykernel_12264\1842923076.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(

# %%
df.head(5)
# Out:
#   Unidade da Federação  1992/Mar  1992/Abr  1993/Mai  1993/Dez  1994/Jan  \
# 0          11 Rondônia       NaN       NaN       NaN       NaN       NaN
# 1              12 Acre       NaN       NaN       NaN       NaN       NaN
# 2          13 Amazonas       NaN       NaN       NaN       NaN       NaN
# 3           14 Roraima       NaN       NaN       NaN       NaN       NaN
# 4              15 Pará       NaN       NaN       NaN       NaN       NaN
#
#    1994/Fev  1994/Mai  1994/Ago  1994/Nov  ...     2021/Jan     2021/Fev  \
# 0       NaN       NaN       NaN       NaN  ...  10045624.39  10677245.18
# 1       NaN       NaN       NaN       NaN  ...   4175526.06   5282655.42
# 2       NaN       NaN       NaN       NaN  ...  27406458.57  22341042.63
# 3       NaN       NaN       NaN       NaN  ...   3557821.99   4172285.82
# 4       NaN       NaN       NaN       NaN  ...  39042349.46  37113440.70
#
#       2021/Mar     2021/Abr     2021/Mai     2021/Jun     2021/Jul  \
# ...

# %%
df.tail(13)
# Out:
#      Unidade da Federação  1992/Mar  1992/Abr  1993/Mai  1993/Dez  1994/Jan  \
# 14             28 Sergipe       NaN       NaN       NaN       NaN       NaN
# 15               29 Bahia       NaN       NaN       NaN       NaN       NaN
# 16        31 Minas Gerais       NaN       NaN       NaN       NaN       NaN
# 17      32 Espírito Santo       NaN       NaN       NaN       NaN       NaN
# 18      33 Rio de Janeiro       NaN       NaN       NaN       NaN       NaN
# 19           35 São Paulo  40243.16  11449.99  34583.77  68556.52  39809.34
# 20              41 Paraná       NaN       NaN       NaN       NaN       NaN
# 21      42 Santa Catarina       NaN       NaN       NaN       NaN       NaN
# 22   43 Rio Grande do Sul       NaN       NaN       NaN       NaN       NaN
# 23  50 Mato Grosso do Sul       NaN       NaN       NaN       NaN       NaN
# 24         51 Mato Grosso       NaN       NaN       NaN       NaN       NaN
# ...

# %%
df.dtypes
# Out:
# Unidade da Federação     object
# 1992/Mar                float64
# 1992/Abr                float64
# 1993/Mai                float64
# 1993/Dez                float64
#                          ...
# 2021/Jun                float64
# 2021/Jul                float64
# 2021/Ago                float64
# 2021/Set                float64
# Total                   float64
# Length: 293, dtype: object

# %%
# Tirando a média das colunas
df.mean()
# Out:
# C:\Users\corpc34475\AppData\Local\Temp\ipykernel_12264\3346268648.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# 1992/Mar    4.024316e+04
# 1992/Abr    1.144999e+04
# 1993/Mai    3.458377e+04
# 1993/Dez    6.855652e+04
# 1994/Jan    3.980934e+04
#                 ...
# 2021/Jun    7.759041e+07
# 2021/Jul    6.084629e+07
# 2021/Ago    4.388572e+07
# 2021/Set    1.912632e+07
# Total       6.852321e+09
# Length: 292, dtype: float64

# %%
# Alterando o formatação de número científico para decimal com 2 casas decimais
pd.options.display.float_format = '{:.2f}'.format

# %%
df.mean()
# Out:
# C:\Users\corpc34475\AppData\Local\Temp\ipykernel_12264\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# 1992/Mar        40243.16
# 1992/Abr        11449.99
# 1993/Mai        34583.77
# 1993/Dez        68556.52
# 1994/Jan        39809.34
#                 ...
# 2021/Jun     77590406.47
# 2021/Jul     60846287.01
# 2021/Ago     43885716.30
# 2021/Set     19126320.76
# Total      6852320913.49
# Length: 292, dtype: float64
